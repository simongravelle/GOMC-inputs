# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a = np.array([-0.9572, 0.0, 0.0]) 
b = np.array([0.0, 0.0, 0.0 ]) 
c = np.array([0.9572*np.sin((104.52-90)*np.pi/180),
              0.9572*np.cos((104.52-90)*np.pi/180),
              0.0 ]) 
d = np.array([-0.1546*np.cos((104.52/2)*np.pi/180),
              0.1546*np.sin((104.52/2)*np.pi/180),
              0.0 ]) 

print(a)
print(b)
print(c)
print(d)
# Out:
# [-0.9572  0.      0.    ]
# [0. 0. 0.]
# [0.23998721 0.92662721 0.        ]
# [-0.09462746  0.12225713  0.        ]

# %%
an = np.linspace(0, 2 * np.pi, 100)
fig, axs = plt.subplots()
x = np.linspace(0, 1)
axs.plot(x*0, x, "k")
axs.plot(x*0+1, x, "k")
axs.plot(x, x*0, "k")
axs.plot(x, x*0+1, "k")

axs.plot(a[0], a[1], 'or')
axs.plot(b[0], b[1], 'or')
axs.plot(c[0], c[1], 'or')
axs.plot(d[0], d[1], 'or')

axs.set_aspect('equal', 'box')
